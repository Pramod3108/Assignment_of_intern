# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
wine_ds = pd.read_csv(r"D:\Data Science\Wine-Quality-1Phase\winequality-red.csv")
wine_ds
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_ds.shape
# Out:
# (1599, 12)

# %%
wine_ds.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine_ds.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine_ds.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
sns.catplot(x='quality', data=wine_ds, kind='count')

# %% [markdown]
# ### volatile acidity vs quality

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y ='volatile acidity', data = wine_ds)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %% [markdown]
# ### citric acid vs quality

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x='quality', y ='citric acid', data = wine_ds)
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %% [markdown]
# ### Correlation

# %%
correlation = wine_ds.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(correlation, cbar=True, square=True, fmt='1f', annot=True ,annot_kws={'size':8}, cmap='Blues' )
# Out:
# <Axes: >

# %% [markdown]
# #### Data_Preprocessing

# %%
#sperate the data & lable

# %%
X = wine_ds.drop('quality',axis=1)

# %%
print(X)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # lable Binarization

# %%
Y = wine_ds['quality'].apply(lambda y_value: 1 if y_value>=7 else 0)

# %%
X = wine_ds['quality'].apply(lambda y_value: 1 if y_value>=7 else 0)

# %%
print(Y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1599, dtype: int64

# %% [markdown]
# # train & test data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=3)

# %%
print(Y.shape, Y_train.shape, Y_test.shape)
# Out:
# (1599,) (1279,) (320,)

# %% [markdown]
# # Model Training

# %% [markdown]
# #### Random Forest Classifier

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 model.fit(X_train, Y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:348, in BaseForest.fit(self, X, y, sample_weight)
#     346 if issparse(y):
#     347     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 348 X, y = self._validate_data(
#     349     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     350 )
# ...

# %%
#Model Evelution
# Accurecy Score

# %%
X_test_prediction = Model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 X_test_prediction = Model.predict(X_test)
#       2 test_data_accuracy = accuracy_score(X_test_prediction,Y_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:823, in ForestClassifier.predict(self, X)
#     802 def predict(self, X):
#     803     """
#     804     Predict class for X.
#     805
#    (...)
#     821         The predicted classes.
#     822     """
# --> 823     proba = self.predict_proba(X)
#     825     if self.n_outputs_ == 1:
#     826         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:863, in ForestClassifier.predict_proba(self, X)
#     841 def predict_proba(self, X):
#     842     """
#     843     Predict class probabilities for X.
#     844
#    (...)
# ...

# %%
print('Accuracy : ---> ' , test_data_accuracy)
# Out:
# Accuracy : --->  0.9375

# %% [markdown]
# #### bulding a prdective system

# %%
input_data = (7.3,0.65,0.0,1.2,0.065,15.0,21.0,0.9946,3.39,0.47,10.0)

#Changing the data to a numpy array

input_data_as_numpy_array = np.asarray(input_data)

# %%
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# %%
 predition = Model.predict(input_data_reshaped)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 predition = Model.predict(input_data_reshaped)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:823, in ForestClassifier.predict(self, X)
#     802 def predict(self, X):
#     803     """
#     804     Predict class for X.
#     805
#    (...)
#     821         The predicted classes.
#     822     """
# --> 823     proba = self.predict_proba(X)
#     825     if self.n_outputs_ == 1:
#     826         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:863, in ForestClassifier.predict_proba(self, X)
#     841 def predict_proba(self, X):
#     842     """
#     843     Predict class probabilities for X.
#     844
#    (...)
#     861         classes corresponds to that in the attribute :term:`classes_`.
# ...

# %%
predition = Model.predict(input_data_reshaped)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 predition = Model.predict(input_data_reshaped)
#
# NameError: name 'Model' is not defined
